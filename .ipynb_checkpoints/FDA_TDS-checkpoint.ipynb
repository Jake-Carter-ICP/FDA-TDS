# %% [raw]
# ---
# title: "Quarto Basics"
# format:
#   html:
#     code-fold: false
# jupyter: python3
# ---

# %% [markdown]
# #### This notebook describes some exploratory data analysis on the FDA Total Diet Study (https://www.fda.gov/food/reference-databases-and-monitoring-programs-food/fda-total-diet-study-tds).
#
# #### All data is public, located at https://www.fda.gov/food/fda-total-diet-study-tds/fda-total-diet-study-tds-results and https://www.fda.gov/food/fda-total-diet-study-tds/fda-total-diet-study-tds-1991-2017.

# %% [markdown]
# # First we load in the libraries and set defaults

# %%
import pandas as pd
import numpy as np
from itables import init_notebook_mode
init_notebook_mode(all_interactive=False)
from itables import show
from PIL import Image
from IPython.display import display

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

pd.options.display.max_columns = None
pd.options.display.max_rows = 500
# Out:
# <script>
#     if (document.body.dataset.jpThemeLight == "false" || // Jupyter Lab
#         document.body.dataset.vscodeThemeKind == "vscode-dark" || // VS Code
#         document.documentElement.dataset.theme == "dark" || // Jupyter Book
#         window.matchMedia('(prefers-color-scheme: dark)').matches) {
#         document.documentElement.classList.add('dark');
#     }
#     else {
#         document.documentElement.classList.remove('dark');
#     }
# </script>
# <style>:root{--dt-row-selected: 13, 110, 253;--dt-row-selected-text: 255, 255, 255;--dt-row-selected-link: 9, 10, 11;--dt-row-stripe: 0, 0, 0;--dt-row-hover: 0, 0, 0;--dt-column-ordering: 0, 0, 0;--dt-html-background: white}:root.dark{--dt-html-background: rgb(33, 37, 41)}table.dataTable td.dt-control{text-align:center;cursor:pointer}table.dataTable td.dt-control:before{display:inline-block;box-sizing:border-box;content:"";border-top:5px solid transparent;border-left:10px solid rgba(0,0,0,.5);border-bottom:5px solid transparent;border-right:0px solid transparent}table.dataTable tr.dt-hasChild td.dt-control:before{border-top:10px solid rgba(0,0,0,.5);border-left:5px solid transparent;border-bottom:0px solid transparent;border-right:5px solid transparent}html.dark table.dataTable td.dt-control:before,:root[data-bs-theme=dark] table.dataTable td.dt-control:before{border-left-color:#ffffff80}html.dark table.dataTable tr.dt-hasChild td.dt-control:before,:root[data-bs-theme=dark] table.dataTable tr.dt-hasChild td.dt-control:before{border-top-color:#ffffff80;border-left-color:transparent}div.dt-scroll-body thead tr,div.dt-scroll-body tfoot tr{height:0}div.dt-scroll-body thead tr th,div.dt-scroll-body thead tr td,div.dt-scroll-body tfoot tr th,div.dt-scroll-body tfoot tr td{height:0!important;padding-top:0!important;padding-bottom:0!important;border-top-width:0px!important;border-bottom-width:0px!important}div.dt-scroll-body thead tr th div.dt-scroll-sizing,div.dt-scroll-body thead tr td div.dt-scroll-sizing,div.dt-scroll-body tfoot tr th div.dt-scroll-sizing,div.dt-scroll-body tfoot tr td div.dt-scroll-sizing{height:0!important;overflow:hidden!important}table.dataTable thead>tr>th.dt-orderable-asc span.dt-column-order:before,table.dataTable thead>tr>th.dt-ordering-asc span.dt-column-order:before,table.dataTable thead>tr>td.dt-orderable-asc span.dt-column-order:before,table.dataTable thead>tr>td.dt-ordering-asc span.dt-column-order:before{position:absolute;display:block;bottom:50%;content:"\25b2";content:"\25b2"/""}table.dataTable thead>tr>th.dt-orderable-desc span.dt-column-order:after,table.dataTable thead>tr>th.dt-ordering-desc span.dt-column-order:after,table.dataTable thead>tr>td.dt-orderable-desc span.dt-column-order:after,table.dataTable thead>tr>td.dt-ordering-desc span.dt-column-order:after{position:absolute;display:block;top:50%;content:"\25bc";content:"\25bc"/""}table.dataTable thead>tr>th.dt-orderable-asc,table.dataTable thead>tr>th.dt-orderable-desc,table.dataTable thead>tr>th.dt-ordering-asc,table.dataTable thead>tr>th.dt-ordering-desc,table.dataTable thead>tr>td.dt-orderable-asc,table.dataTable thead>tr>td.dt-orderable-desc,table.dataTable thead>tr>td.dt-ordering-asc,table.dataTable thead>tr>td.dt-ordering-desc{position:relative;padding-right:30px}table.dataTable thead>tr>th.dt-orderable-asc span.dt-column-order,table.dataTable thead>tr>th.dt-orderable-desc span.dt-column-order,table.dataTable thead>tr>th.dt-ordering-asc span.dt-column-order,table.dataTable thead>tr>th.dt-ordering-desc span.dt-column-order,table.dataTable thead>tr>td.dt-orderable-asc span.dt-column-order,table.dataTable thead>tr>td.dt-orderable-desc span.dt-column-order,table.dataTable thead>tr>td.dt-ordering-asc span.dt-column-order,table.dataTable thead>tr>td.dt-ordering-desc span.dt-column-order{position:absolute;right:12px;top:0;bottom:0;width:12px}table.dataTable thead>tr>th.dt-orderable-asc span.dt-column-order:before,table.dataTable thead>tr>th.dt-orderable-asc span.dt-column-order:after,table.dataTable thead>tr>th.dt-orderable-desc span.dt-column-order:before,table.dataTable thead>tr>th.dt-orderable-desc span.dt-column-order:after,table.dataTable thead>tr>th.dt-ordering-asc span.dt-column-order:before,table.dataTable thead>tr>th.dt-ordering-asc span.dt-column-order:after,table.dataTable thead>tr>th.dt-ordering-desc span.dt-column-order:before,table.dataTable thead>tr>th.dt-ordering-desc span.dt-column-order:after,table.dataTable thead>tr>td.dt-o ...

# %% [markdown]
# # Now we read in the data files

# %%
years=list(range(1991, 2017))

years=[str(x) + ".txt" for x in years]

# %%
years=["Elements " + s for s in years]
years = ["C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/" + s for s in years]
years
# Out:
# ['C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 1991.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 1992.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 1993.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 1994.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 1995.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 1996.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 1997.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 1998.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 1999.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2000.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2001.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2002.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2003.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2004.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2005.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2006.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2007.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2008.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2009.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2010.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2011.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2012.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2013.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2014.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2015.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2016.txt']

# %%
files = years + ["C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2017 MB 1-3.txt", "C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2017 MB 4.txt"]
files
# Out:
# ['C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 1991.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 1992.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 1993.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 1994.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 1995.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 1996.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 1997.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 1998.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 1999.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2000.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2001.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2002.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2003.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2004.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2005.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2006.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2007.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2008.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2009.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2010.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2011.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2012.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2013.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2014.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2015.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2016.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2017 MB 1-3.txt',
#  'C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/Elements 2017 MB 4.txt']

# %%
data_read = []

for file in files:
  data_read.append(pd.read_table(file, encoding = 'latin-1'))

data_read.append(pd.read_csv("C:/Users/carte/OneDrive/Documents/FDA/TDS/elements/2018_2020.csv"))

# %% [markdown]
# # Initial Data Exploration: Shape and Data Types

# %%
df = pd.concat(data_read)
df.shape
# Out:
# (429946, 37)

# %%
df.dtypes
# Out:
# MB                              float64
# Food No.                        float64
# Food Name                        object
# Anal Type                        object
# Sample Qualifier                 object
# Replicate No.                    object
# Element                          object
# Conc                            float64
# Unit                             object
# Trace                            object
# LOD                             float64
# LOQ                             float64
# Result Qualifier and Remarks     object
# Method                           object
# Instrument                       object
# Batch ID                         object
# METHOD                           object
# Food No                         float64
# ReplicateNo                      object
# Reference Material               object
# QC Level                         object
# QC Unit                          object
# QC% Recvd                        object
# City ID                          object
# Replicate No                    float64
# FiscalYear                      float64
# CalendarYear                    float64
# Collection                      float64
# TDSFoodNumber                   float64
# TDSFoodDescription               object
# Season                           object
# TDSFoodListType                  object
# Region                           object
# Analyte                          object
# Units                            object
# Concentration                   float64
# ReportingLimit                  float64
# dtype: object

# %%
img = Image.open('C:/Users/carte/OneDrive/Documents/GitHub/FDA-TDS/elements_column_key.PNG')
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=512x600>

# %% [markdown]
# # Inital Data Exploration Inlcuding Some Data Cleaning

# %% [markdown]
# Fixing column names

# %%
df.columns = df.columns\
    .str.replace(" ", "_")\
    .str.replace(".", "_")\
    .str.replace("%", "_percent_")
df.columns
# Out:
# Index(['MB', 'Food_No_', 'Food_Name', 'Anal_Type', 'Sample_Qualifier',
#        'Replicate_No_', 'Element', 'Conc', 'Unit', 'Trace', 'LOD', 'LOQ',
#        'Result_Qualifier_and_Remarks', 'Method', 'Instrument', 'Batch_ID',
#        'METHOD', 'Food_No', 'ReplicateNo', 'Reference_Material', 'QC_Level',
#        'QC_Unit', 'QC_percent__Recvd', 'City_ID', 'Replicate_No', 'FiscalYear',
#        'CalendarYear', 'Collection', 'TDSFoodNumber', 'TDSFoodDescription',
#        'Season', 'TDSFoodListType', 'Region', 'Analyte', 'Units',
#        'Concentration', 'ReportingLimit'],
#       dtype='object')

# %% [markdown]
# Fixing Food_Name

# %%
df['Food_Name'] = df['Food_Name']\
    .str.replace('w/', 'with')\
    .str.upper()\
    .str.replace(', ', '_').str.upper()\
    .str.replace(' ', '_').str.upper()\
    .str.removesuffix('_')

#df['Food.Name'].unique()

# %% [markdown]
# From column key, we see the first four digits of MB are the year. The last two digits are the specific market basket. Let's extract this information.

# %%
df['Year'] = df.MB.astype(str).str[:4].astype(float)

# %%
df['Market_Basket'] = df.MB.astype(str).str[-4:]

# %% [raw]
# What's missing in the data

# %%
df.isnull().sum()
# Out:
# MB                               58079
# Food_No_                         90743
# Food_Name                        58079
# Anal_Type                        58079
# Sample_Qualifier                307204
# Replicate_No_                   354905
# Element                          58079
# Conc                             58079
# Unit                             58079
# Trace                           370168
# LOD                              59909
# LOQ                              59909
# Result_Qualifier_and_Remarks    319556
# Method                          137807
# Instrument                       58081
# Batch_ID                        173749
# METHOD                          350220
# Food_No                         397282
# ReplicateNo                     415226
# Reference_Material              415226
# QC_Level                        415226
# QC_Unit                         415226
# QC_percent__Recvd               415226
# City_ID                         429833
# Replicate_No                    429469
# FiscalYear                      371867
# CalendarYear                    371867
# Collection                      371867
# TDSFoodNumber                   371867
# TDSFoodDescription              371867
# Season                          371867
# TDSFoodListType                 371867
# Region                          371868
# Analyte                         371868
# Units                           371868
# Concentration                   371868
# ReportingLimit                  371868
# Year                             58079
# Market_Basket                        0
# dtype: int64

# %% [markdown]
# Let's get the Unit vs Units worked out

# %%
df['Unit']=df['Unit'].str.replace(' ', '')
df['Unit'].unique()
# Out:
# array(['mg/kg', '%', 'ug/kg', nan], dtype=object)

# %% [markdown]
# What are the null entries?
# Trying to figure out if the difference in null units between Unit and Units

# %%
(pd.isnull(df['Units']) & pd.isnull(df['Unit'])).sum()
# Out:
# 1

# %% [markdown]
# So there are is one row where Unit and Units are empty

# %%
df = df[~(pd.isnull(df['Units']) & pd.isnull(df['Unit']))].copy()

# %%
df.shape
# Out:
# (429945, 39)

# %%
pd.isnull(df['Units']).sum()
# Out:
# 371867

# %%
pd.isnull(df['Unit']).sum()
# Out:
# 58078

# %%
pd.isnull(df['Units']).sum() + pd.isnull(df['Unit']).sum()
# Out:
# 429945

# %% [markdown]
# So we are going to simply substitute for Unit and drop ['Units']

# %%
def replace_null_with_column(df, col_a, col_b):
    df[col_a] = df.apply(lambda row: row[col_b] if pd.isnull(row[col_a]) else row[col_a], axis=1)
    return df

# %%
df = replace_null_with_column(df, 'Unit', 'Units')

# %%
pd.isnull(df['Unit']).sum()
# Out:
# 0

# %%
df = df.drop(['Units'], axis = 1)

# %%
(pd.isnull(df['Conc']) & pd.isnull(df['Concentration'])).sum()
# Out:
# 0

# %%
df['Conc'].isnull().sum()
# Out:
# 58078

# %%
df['Concentration'].isnull().sum()
# Out:
# 371867

# %%
df['Conc'].isnull().sum() + df['Concentration'].isnull().sum()
# Out:
# 429945

# %% [markdown]
# So just like above we need to substitute for Conc

# %%
df = replace_null_with_column(df, 'Conc', 'Concentration')

# %%
df['Conc'].isnull().sum()
# Out:
# 0

# %%
df = df.drop(['Concentration'], axis = 1)

# %%
df['Element'].isnull().sum()
# Out:
# 58078

# %%
df['Analyte'].isnull().sum()
# Out:
# 371867

# %%
df['Element'].isnull().sum() + df['Analyte'].isnull().sum()
# Out:
# 429945

# %%
df = replace_null_with_column(df, 'Element', 'Analyte')

# %%
df = df.drop(['Analyte'], axis = 1)

# %%
df.columns
# Out:
# Index(['MB', 'Food_No_', 'Food_Name', 'Anal_Type', 'Sample_Qualifier',
#        'Replicate_No_', 'Element', 'Conc', 'Unit', 'Trace', 'LOD', 'LOQ',
#        'Result_Qualifier_and_Remarks', 'Method', 'Instrument', 'Batch_ID',
#        'METHOD', 'Food_No', 'ReplicateNo', 'Reference_Material', 'QC_Level',
#        'QC_Unit', 'QC_percent__Recvd', 'City_ID', 'Replicate_No', 'FiscalYear',
#        'CalendarYear', 'Collection', 'TDSFoodNumber', 'TDSFoodDescription',
#        'Season', 'TDSFoodListType', 'Region', 'ReportingLimit', 'Year',
#        'Market_Basket'],
#       dtype='object')

# %%
df.shape
# Out:
# (429945, 36)

# %% [markdown]
# Let's fix the food names and food ID

# %%
(df.Food_No.isnull() & df.Food_No_.isnull()).sum()
# Out:
# 58078

# %%
df.Food_No.isnull().sum()
# Out:
# 397281

# %%
df = replace_null_with_column(df, 'Food_No', 'Food_No_')

# %%
df.Food_No.isnull().sum()
# Out:
# 58078

# %%
df = df.drop(['Food_No_'], axis = 1)

# %% [markdown]
# # Exploring Missing Information in Depth

# %%
food_names_without_no = df[df.Food_No.isnull()].Food_Name.unique()

# %%
show(df[['Food_Name', "Food_No"]].drop_duplicates())
# Out:
# <table id="itables_9d11fb6d_36ac_45c3_ba6a_d9f23ed6f7db" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Food_Name</th>
#       <th>Food_No</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.1.3 from the <code>init_notebook_mode</code> cell...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <script type="module">
#     const { DataTable, jQuery: $ } = await import(window._datatables_src_for_itables_2_1_3);
#
#     document.querySelectorAll("#itables_9d11fb6d_36ac_45c3_ba6a_d9f23ed6f7db:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [[0, "WHOLE_MILK_FLUID", 1.0], [13, "LOWFAT_(2%_FAT)_MILK_FLUID", 2.0], [27, "CHOCOLATE_MILK_FLUID", 3.0], [40, "SKIM_MILK_FLUID", 4.0], [53, "PLAIN_YOGURT_LOWFAT", 6.0], [66, "CHOCOLATE_MILK_SHAKE_FAST-FOOD", 7.0], [79, "EVAPORATED_MILK_CANNED", 8.0], [92, "AMERICAN_PROCESSED_CHEESE", 10.0], [104, "COTTAGE_CHEESE_4%_MILKFAT", 11.0], [117, "CHEDDAR_CHEESE", 12.0], [130, "GROUND_BEEF_PAN-COOKED", 13.0], [143, "BEEF_CHUCK_ROAST_BAKED", 14.0], [156, "BEEF_STEAK_LOIN_PAN-COOKED", 16.0], [169, "HAM_BAKED", 17.0], [182, "PORK_CHOP_PAN-COOKED", 18.0], [195, "PORK_SAUSAGE_PAN-COOKED", 19.0], [208, "PORK_BACON_PAN-COOKED", 20.0], [221, "PORK_ROAST_BAKED", 21.0], [234, "LAMB_CHOP_PAN-COOKED", 22.0], [247, "CHICKEN_FRIED_(BREAST_LEG_AND_THIGH)_HOMEMADE", 24.0], [261, "TURKEY_BREAST_ROASTED", 26.0], [275, "LIVER_BEEF_FRIED", 27.0], [289, "FRANKFURTERS_BEEF_BOILED", 28.0], [302, "BOLOGNA_SLICED", 29.0], [315, "SALAMI_SLICED", 30.0], [328, "TUNA_CANNED_IN_OIL", 32.0], [342, "FISH_STICKS_FROZEN_HEATED", 34.0], [356, "EGGS_SCRAMBLED", 35.0], [370, "EGGS_FRIED", 36.0], [384, "EGGS_BOILED", 37.0], [398, "PINTO_BEANS_DRY_BOILED", 38.0], [411, "PORK_AND_BEANS_CANNED", 39.0], [424, "LIMA_BEANS_IMMATURE_FROZEN_BOILED", 42.0], [437, "GREEN_PEAS_FRESH/FROZEN_BOILED", 46.0], [450, "PEANUT_BUTTER_SMOOTH", 47.0], [463, "PEANUTS_DRY_ROASTED", 48.0], [476, "WHITE_RICE_COOKED", 50.0], [490, "OATMEAL_QUICK_(1-3
H/FROZEN_BOILED", 116.0], [1256, "TOMATO_RED_RAW", 117.0], [1270, "TOMATO_SAUCE_PLAIN_BOTTLED", 119.0], [1283, "GREEN_BEANS_FRESH/FROZEN_BOILED", 121.0], [1296, "CUCUMBER_RAW", 123.0], [1309, "SUMMER_SQUASH_FRESH/FROZEN_BOILED", 124.0], [1322, "GREEN_PEPPER_RAW", 125.0], [1335, "WINTER_SQUASH_FRESH/FROZEN_BAKED_MASHED", 126.0], [1348, "ONION_MATURE_RAW", 128.0], [1361, "RADISH_RAW", 132.0], [1374, "FRENCH_FRIES_FROZEN_HEATED", 134.0], [1387, "MASHE ...

# %% [markdown]
# We are trying to figure out what food ID numbers arent in the range of 1 to food ID MAX

# %%
df.Food_No.isnull().sum()
# Out:
# 58078

# %%
food_id_range = np.arange(1,
    df['Food_No']\
    .dropna()\
    .unique()\
    .max(),
    dtype='int')

# %% [markdown]
# So what Food IDs are not present?

# %%
food_ids_not_in_df = food_id_range[~np.isin(food_id_range, df['Food_No'].dropna().drop_duplicates())]
food_ids_not_in_df
# Out:
# array([  5,   9,  15,  23,  25,  31,  33,  40,  41,  43,  44,  45,  49,
#         82,  90, 101, 102, 104, 106, 118, 120, 127, 129, 130, 133, 141,
#        144, 150, 153, 154, 158, 159, 163, 165, 171, 174, 176, 180, 181,
#        189, 192, 195, 204, 206, 217, 228, 229, 234, 315, 321, 322, 329,
#        330, 349, 383, 384, 405, 406, 407, 408, 409, 410, 411, 412, 413,
#        414, 415, 416, 417, 418, 419, 420, 421, 422, 423, 424, 425, 426,
#        427, 428, 429, 430, 431, 432, 433, 434, 435, 436, 437, 438, 439,
#        440, 441, 442, 443, 444, 445, 446, 447, 448, 449, 450, 451, 452,
#        453, 454, 455, 456, 457, 458, 459, 460, 461, 462, 463, 464, 465,
#        466, 467, 468, 469, 470, 471, 472, 473, 474, 475, 476, 477, 478,
#        479, 480, 481, 482, 483, 484, 485, 486, 487, 488, 489, 490, 491,
#        492, 493, 494, 495, 496, 497, 498, 499, 500, 501, 502, 503, 504,
#        505, 506, 507, 508, 509, 510, 511, 512, 513, 514, 515, 516, 517,
#        518, 519, 520, 521, 522, 523, 524, 525, 526, 527, 528, 529, 530,
#        531, 532, 533, 534, 535, 536, 537, 538, 539, 540, 541, 542, 543,
#        544, 545, 546, 547, 548, 549, 550, 551, 552, 553, 554, 555, 556,
#        557, 558, 559, 560, 561, 562, 563, 564, 565, 566, 567, 568, 569,
#        570, 571, 572, 573, 574, 575, 576, 577, 578, 579, 580, 581, 582,
#        583, 584, 585, 586, 587, 588, 589, 590, 591, 592, 593, 594, 595,
#        596, 597, 598, 599, 600, 601, 602, 603, 604, 605, 606, 607, 608,
#        609, 610, 611, 612, 613, 614, 615, 616, 617, 618, 619, 620, 621,
#        622, 623, 624, 625, 626, 627, 628, 629, 630, 631, 632, 633, 634,
#        635, 636, 637, 638, 639, 640, 641, 642, 643, 644, 645, 646, 647,
#        648, 649, 650, 651, 652, 653, 654, 655, 656, 657, 658, 659, 660,
#        661, 662, 663, 664, 665, 666, 667, 668, 669, 670, 671, 672, 673,
#        674, 675, 676, 677, 678, 679, 680, 681, 682, 683, 684, 685, 686,
#        687, 688, 689, 690, 691, 692, 693, 694, 695, 696, 697, 698, 699,
#        702, 706, 707, 708, 709, 716, 718])

# %%
food_name_ID = df[['Food_Name', "Food_No"]].drop_duplicates()
show(food_name_ID[~food_name_ID.Food_No.isnull()])
# Out:
# <table id="itables_e7cca234_8d54_498a_9a7f_13ca3c1fbe36" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Food_Name</th>
#       <th>Food_No</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.1.3 from the <code>init_notebook_mode</code> cell...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <script type="module">
#     const { DataTable, jQuery: $ } = await import(window._datatables_src_for_itables_2_1_3);
#
#     document.querySelectorAll("#itables_e7cca234_8d54_498a_9a7f_13ca3c1fbe36:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [[0, "WHOLE_MILK_FLUID", 1.0], [13, "LOWFAT_(2%_FAT)_MILK_FLUID", 2.0], [27, "CHOCOLATE_MILK_FLUID", 3.0], [40, "SKIM_MILK_FLUID", 4.0], [53, "PLAIN_YOGURT_LOWFAT", 6.0], [66, "CHOCOLATE_MILK_SHAKE_FAST-FOOD", 7.0], [79, "EVAPORATED_MILK_CANNED", 8.0], [92, "AMERICAN_PROCESSED_CHEESE", 10.0], [104, "COTTAGE_CHEESE_4%_MILKFAT", 11.0], [117, "CHEDDAR_CHEESE", 12.0], [130, "GROUND_BEEF_PAN-COOKED", 13.0], [143, "BEEF_CHUCK_ROAST_BAKED", 14.0], [156, "B
TAIL_CANNED_IN_HEAVY_SYRUP", 87.0], [949, "GRAPES_RED/GREEN_SEEDLESS_RAW", 88.0], [962, "CANTALOUPE_RAW", 89.0], [975, "PLUMS_RAW", 91.0], [988, "GRAPEFRUIT_RAW", 92.0], [1001, "PINEAPPLE_CANNED_IN_JUICE", 93.0], [1014, "RAISINS_DRIED", 95.0], [1028, "PRUNES_DRIED", 96.0], [1042, "AVOCADO_RAW", 97.0], [1056, "ORANGE_JUICE_FROM_FROZEN_CONCENTRATE", 98.0], [1070, "APPLE_JUICE_BOTTLED", 99.0], [1084, "GRAPEFRUIT_JUICE_FROM_FROZEN_CONCENTRATE", 100.0], [1097, "PRUNE_JUICE_BOTTLED", 103.0], [1110, "LEMONADE_FROM_FROZEN_CONCENTRATE", 105.0], [1123, "SPINACH_FRESH/FROZEN_BOILED", 107.0], [1137, "COLLARDS_FRESH/FROZEN_BOILED", 108.0], [1151, "ICEBERG_LETTUCE_RAW", 109.0], [1164, "CABBAGE_FRESH_BOILED", 110.0], [1177, "COLESLAW_WITH_DRESSING_HOMEMADE", 111.0], [1190, "SAUERKRAUT_CANNED", 112.0], [1203, "BROCCOLI_FRESH/FROZEN_BOILED", 113.0], [1216, "CELERY_RAW", 114.0], [1229, "ASPARAGUS_FRESH/FROZEN_BOILED", 115.0], [1242, "CAULIFLOWER_FRESH/FROZEN_BOILED", 116.0], [1256, "TOMATO_RED_RAW", 117.0], [1270, "TOMATO_SAUCE_PLAIN_BOTTLED", 119.0], [1283, "GREEN_BEANS_FRESH/FROZEN_BOILED", 121.0], [1296, "CUCUMBER_RAW", 123.0], [1309, "SUMMER_SQUASH_FRESH/FROZEN_BOILED", 124.0], [1322, "GREEN_PEPPER_RAW", 125.0], [1335, "WINTER_SQUASH_FRESH/FROZEN_BAKED_MASHED", 126.0], [1348, "ONION_MATURE_RAW", 128.0], [1361, "RADISH_RAW", 132.0], [1374, "FRENCH_FRIES_FROZEN_HEATED", 134.0], [1387, "MASHE ...

# %% [markdown]
# # More Data Cleaning

# %% [markdown]
# Let's now work on the units variable

# %%
df['Conc_mgkg'] = np.where(df['Unit']=="ug/kg", df['Conc']/1000, df['Conc'])
df['Conc_mgkg'] = np.where(df['Unit']=="ppb", df['Conc']/1000, df['Conc'])

# %%
df = df.drop(['Conc'], axis = 1)

# %% [markdown]
# Fix capitalization in the elements variable

# %%
df['Element']=df.Element.str.upper()
df['Element'].unique()
# Out:
# array(['ARSENIC', 'CADMIUM', 'CALCIUM', 'COPPER', 'IRON', 'LEAD',
#        'MAGNESIUM', 'MERCURY', 'PHOSPHORUS', 'POTASSIUM', 'SELENIUM',
#        'SODIUM', 'ZINC', 'MANGANESE', 'NICKEL', 'IODINE', 'ANTIMONY',
#        'ALUMINUM', 'MOLYBDENUM', 'WATER (ANALYSIS FOR TOTAL DIET ONLY)',
#        'BARIUM', 'BERYLLIUM', 'CHROMIUM', 'DIMETHYLARSINIC ACID ',
#        'MONOMETHYLARSONIC ACID ', 'SILVER', 'THALLIUM',
#        'TOTAL INORGANIC ARSENIC ', 'URANIUM', 'DIMETHYLARSINIC ACID',
#        'MONOMETHYLARSONIC ACID', 'STRONTIUM', 'TOTAL INORGANIC ARSENIC',
#        'VANADIUM', 'CALCIUM ', 'CHROMIUM ', 'COPPER ', 'IODINE ', 'IRON ',
#        'MAGNESIUM ', 'MANGANESE ', 'MOLYBDENUM ', 'POTASSIUM ',
#        'PHOSPHORUS ', 'SELENIUM ', 'SODIUM ', 'ZINC ', 'ARSENIC (TOTAL) ',
#        'CADMIUM ', 'LEAD ', 'MERCURY ', 'NICKEL ', 'STRONTIUM ',
#        'URANIUM ', 'VANADIUM ', 'ANTIMONY ', 'BARIUM ', 'BERYLLIUM ',
#        'THALLIUM '], dtype=object)

# %% [markdown]
# So what are the percent units data

# %%
df_percent = df.query('Unit == "%"').copy()
show(df_percent)
# Out:
# <table id="itables_ddf35ca6_5cb6_4e45_a9b7_ee20c661f4da" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MB</th>
#       <th>Food_Name</th>
#       <th>Anal_Type</th>
#       <th>Sample_Qualifier</th>
#       <th>Replicate_No_</th>
#       <th>Element</th>
#       <th>Unit</th>
#       <th>Trace</th>
#       <th>LOD</th>
#       <th>LOQ</th>
#       <th>Result_Qualifier_and_Remarks</th>
#       <th>Method</th>
#       <th>Instrument</th>
#       <th>Batch_ID</th>
#       <th>METHOD</th>
#       <th>Food_No</th>
#       <th>ReplicateNo</th>
#       <th>Reference_Material</th>
#       <th>QC_Level</th>
#       <th>QC_Unit</th>
#       <th>QC_percent__Recvd</th>
#       <th>City_ID</th>
#       <th>Replicate_No</th>
#       <th>FiscalYear</th>
#       <th>CalendarYear</th>
#       <th>Collection</th>
#       <th>TDSFoodNumber</th>
#       <th>TDSFoodDescription</th>
#       <th>Season</th>
#       <th>TDSFoodListType</th>
#       <th>Region</th>
#       <th>ReportingLimit</th>
#       <th>Year</th>
#       <th>Market_Basket</th>
#       <th>Conc_mgkg</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.1.3 from the <code>init_notebook_mode</code> cell...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <script type="module">
#     const { DataTable, jQuery: $ } = await import(window._datatables_src_for_itables_2_1_3);
#
#     document.querySelectorAll("#itables_ddf35ca6_5cb6_4e45_a9b7_ee20c661f4da:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [[14387, 201102.0, "MILK_WHOLE_FLUID", "O", "UAP ", "  ", "WATER (ANALYSIS FOR TOTAL DIET ONLY)", "%", "NaN", NaN, NaN, "  ", "KCM TD KCX 2 (Microwave; Moisture; Food) ", "MA", "2011-2 ", "NaN", 1.0, "NaN", "NaN", "NaN", "NaN", "NaN", "NaN", NaN, NaN, NaN, NaN, NaN, "NaN", "NaN", "NaN", "NaN", NaN, 2011.0, "02.0", 87.0], [14388, 201102.0, "MILK_LOWFAT_(2%)_FLUID", "O", "UAP ", "  ", "WATER (ANALYSIS FOR TOTAL DIET ONLY)", "%", "NaN", NaN, NaN, "  ", "KCM TD KCX 2 (Microwave; Moisture; Food) ", "MA", "2011-02 ", "NaN", 2.0, "NaN", "NaN", "NaN", "NaN", "NaN", "NaN", NaN, NaN, NaN, Na
ALYSIS FOR TOTAL DIET ONLY)", "%", "NaN", NaN, NaN, "  ", "KCM TD KCX 2 (Microwave; Moisture; Food) ", "MA", "2011-02 ", "NaN", 14.0, "NaN", "NaN", "NaN", "NaN", "NaN", "NaN", NaN, NaN, NaN, NaN, NaN, "NaN", "NaN", "NaN", "NaN", NaN, 2011.0, "02.0", 51.9], [14396, 201102.0, "HAM_CURED_(NOT_CANNED)_BAKED", "O", "UAP ", "  ", "WATER (ANALYSIS FOR TOTAL DIET ONLY)", "%", "NaN", NaN, NaN, "  ", "KCM TD KCX 2 (Microwave; Moisture; Food) ", "MA", "2011-02 ", "NaN", 17.0, "NaN", "NaN", "NaN", "NaN", "NaN", "NaN", NaN, NaN, NaN, NaN, NaN, "NaN", "NaN", "NaN", "NaN", NaN, 2011.0, "02.0", 72.3], [14397, 201102.0, "PORK_CHOP_PAN-COOKED_WITH_OIL", "O",

# %% [markdown]
# Looks like all the % entries are water analysis. How is there conc_mgkg? It's just percent but didnt include that in the if else we want to filter for everything else.

# %% [markdown]
# # Final Filtering for Data We Are Interested In

# %%
df=df.query('Unit != "%"').copy()

# %%
elements = ['ARSENIC', 'CADMIUM', 'CALCIUM', 'COPPER', 'IRON', 'LEAD',
       'MAGNESIUM', 'PHOSPHORUS', 'POTASSIUM', 'SELENIUM', 'MERCURY',
       'SODIUM', 'ZINC', 'MANGANESE', 'NICKEL', 'MOLYBDENUM', 'BARIUM', 'CHROMIUM',

       'THALLIUM',
       'STRONTIUM',
       ]

# %%
elements
# Out:
# ['ARSENIC',
#  'CADMIUM',
#  'CALCIUM',
#  'COPPER',
#  'IRON',
#  'LEAD',
#  'MAGNESIUM',
#  'PHOSPHORUS',
#  'POTASSIUM',
#  'SELENIUM',
#  'MERCURY',
#  'SODIUM',
#  'ZINC',
#  'MANGANESE',
#  'NICKEL',
#  'MOLYBDENUM',
#  'BARIUM',
#  'CHROMIUM',
#  'THALLIUM',
#  'STRONTIUM']

# %% [markdown]
# And we filter down to include the elements of interest

# %%
df = df[df['Element'].isin(elements)].copy()

# %%
df.columns
# Out:
# Index(['MB', 'Food_Name', 'Anal_Type', 'Sample_Qualifier', 'Replicate_No_',
#        'Element', 'Unit', 'Trace', 'LOD', 'LOQ',
#        'Result_Qualifier_and_Remarks', 'Method', 'Instrument', 'Batch_ID',
#        'METHOD', 'Food_No', 'ReplicateNo', 'Reference_Material', 'QC_Level',
#        'QC_Unit', 'QC_percent__Recvd', 'City_ID', 'Replicate_No', 'FiscalYear',
#        'CalendarYear', 'Collection', 'TDSFoodNumber', 'TDSFoodDescription',
#        'Season', 'TDSFoodListType', 'Region', 'ReportingLimit', 'Year',
#        'Market_Basket', 'Conc_mgkg'],
#       dtype='object')

# %%
df.shape
# Out:
# (353956, 35)

# %% [markdown]
# To understand what the columns are referring to see https://www.fda.gov/food/fda-total-diet-study-tds/fda-total-diet-study-tds-results and https://www.fda.gov/media/93359/download?attachment. A screengrab of the column keys is at the top of this notebook.

# %% [markdown]
# After working with the features let's see what is still missing in the data

# %%
df.isnull().sum()
# Out:
# MB                                   0
# Food_Name                            0
# Anal_Type                            0
# Sample_Qualifier                241091
# Replicate_No_                   284074
# Element                              0
# Unit                                 0
# Trace                           298778
# LOD                               1030
# LOQ                               1030
# Result_Qualifier_and_Remarks    254815
# Method                           74167
# Instrument                           2
# Batch_ID                        114586
# METHOD                          279791
# Food_No                              0
# ReplicateNo                     340574
# Reference_Material              340574
# QC_Level                        340574
# QC_Unit                         340574
# QC_percent__Recvd               340574
# City_ID                         353954
# Replicate_No                    353650
# FiscalYear                      353956
# CalendarYear                    353956
# Collection                      353956
# TDSFoodNumber                   353956
# TDSFoodDescription              353956
# Season                          353956
# TDSFoodListType                 353956
# Region                          353956
# ReportingLimit                  353956
# Year                                 0
# Market_Basket                        0
# Conc_mgkg                            0
# dtype: int64

# %% [markdown]
# What are the missing LOD entries?

# %%
df[df.LOQ.isnull()].Element.unique()
# Out:
# array(['NICKEL', 'MERCURY', 'MOLYBDENUM', 'ARSENIC'], dtype=object)

# %%
df[df.LOQ.isnull()].Method.unique()
# Out:
# array([nan, 'FDA EAM Method 4.7 (ICPMS;  As, Cd, Cr, Hg, Pb; Food) ',
#        'KCM TD M2 & E1 (CA, CU,FE, MG, MN, P, K, NA, ZN IN FOOD BY ACID DIGESTION) ',
#        'KCM TD M2 & E5 (AS & SE IN FOOD BY ACID DIGEST. HYDRIDE AA) '],
#       dtype=object)

# %% [markdown]
# I'm not familiar with these methods are so we are going to explude them and filter for when there is an entry for LOQ

# %%
df = df[~df.LOQ.isnull()].copy()

# %%
df.shape
# Out:
# (352926, 35)

# %% [markdown]
# Food Types

# %%
show(
    df[['Food_Name', 'Food_No']].drop_duplicates().reset_index(drop=True)
)
# Out:
# <table id="itables_d452a5c4_c528_4234_bda7_3e336b758ccf" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>Food_Name</th>
#       <th>Food_No</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.1.3 from the <code>init_notebook_mode</code> cell...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <script type="module">
#     const { DataTable, jQuery: $ } = await import(window._datatables_src_for_itables_2_1_3);
#
#     document.querySelectorAll("#itables_d452a5c4_c528_4234_bda7_3e336b758ccf:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [["WHOLE_MILK_FLUID", 1.0], ["LOWFAT_(2%_FAT)_MILK_FLUID", 2.0], ["CHOCOLATE_MILK_FLUID", 3.0], ["SKIM_MILK_FLUID", 4.0], ["PLAIN_YOGURT_LOWFAT", 6.0], ["CHOCOLATE_MILK_SHAKE_FAST-FOOD", 7.0], ["EVAPORATED_MILK_CANNED", 8.0], ["AMERICAN_PROCESSED_CHEESE", 10.0], ["COTTAGE_CHEESE_4%_MILKFAT", 11.0], ["CHEDDAR_CHEESE", 12.0], ["GROUND_BEEF_PAN-COOKED", 13.0], ["BEEF_CHUCK_ROAST_BAKED", 14.0], ["BEEF_STEAK_LOIN_PAN-COOKED", 16.0], ["HAM_BAKED", 17.0], ["PORK_CHOP_PAN-COOKED", 18.0], ["PORK_SAUSAGE_PAN-COOKED", 19.0], ["PORK_BACON_PAN-COOKED", 20.0], ["PORK_ROAST_BAKED", 21
TTLED", 99.0], ["GRAPEFRUIT_JUICE_FROM_FROZEN_CONCENTRATE", 100.0], ["PRUNE_JUICE_BOTTLED", 103.0], ["LEMONADE_FROM_FROZEN_CONCENTRATE", 105.0], ["SPINACH_FRESH/FROZEN_BOILED", 107.0], ["COLLARDS_FRESH/FROZEN_BOILED", 108.0], ["ICEBERG_LETTUCE_RAW", 109.0], ["CABBAGE_FRESH_BOILED", 110.0], ["COLESLAW_WITH_DRESSING_HOMEMADE", 111.0], ["SAUERKRAUT_CANNED", 112.0], ["BROCCOLI_FRESH/FROZEN_BOILED", 113.0], ["CELERY_RAW", 114.0], ["ASPARAGUS_FRESH/FROZEN_BOILED", 115.0], ["CAULIFLOWER_FRESH/FROZEN_BOILED", 116.0], ["TOMATO_RED_RAW", 117.0], ["TOMATO_SAUCE_PLAIN_BOTTLED", 119.0], ["GREEN_BEANS_FRESH/FROZEN_BOILED", 121.0], ["CUCUMBER_RAW", 123.0], ["SUMMER_SQUASH_FRESH/FROZEN_BOILED", 124.0], ["GREEN_PEPPER_RAW", 125.0], ["WINTER_SQUASH_FRESH/FROZEN_BAKED_MASHED", 126.0], ["ONION_MATURE_RAW", 128.0], ["RADISH_RAW", 132.0], ["FRENCH_FRIES_FROZEN_HEATED", 134.0], ["MASHED_POTATOES_FROM_FLAKES", 135.0], ["WHITE_POTATO_BOILED_WITHOUT_SKIN", 136.0], ["WHITE_POTATO_BAKED_WITH_SKIN", 137.0], ["POTATO_CHIPS", 138.0], ["SCALLOPED_POTATOES_HOMEMADE", 139.0], ["SWEET_POTATO_FRESH_BAKED", 140.0], ["SPAGHETTI_WITH_TOMATO_SAUCE_AND_MEATBALLS_HOMEMADE", 142.0], ["BEEF_STEW_WITH_POTATOES_CARROTS_AND_ONION_HOMEMADE", 143.0], ["MACARONI_AND_CHEESE_FROM_BOX_MIX", 146.0], ["QUARTER-POUND_HAMBURGER_ON_BUN_FAST-FOOD", 147.0], ["MEATLOAF_HOMEMADE", 148.0], ["SPAGHETTI_WITH_TOMATO_SAUCE_CANNED", 149.0], ["LASAGNA_WITH_MEAT_HOMEMADE" ...

# %% [markdown]
# Selecting variables of interest

# %%
df_select = \
df[['Food_Name',
    'Food_No',
   'LOD',
   'LOQ',
   'Conc_mgkg',
    'Element',
    'Method',
   'Instrument',
    'MB',
    'Year',
    'Market_Basket']]

df_select.sample(5)
# Out:
#                                Food_Name  Food_No    LOD     LOQ  Conc_mgkg  \
# 9944                          BF_PEACHES    226.0  0.002   0.005      0.003
# 1974   CHOCOLATE_CHIP_COOKIES_COMMERCIAL    183.0  0.800   3.000     35.900
# 6266                        CREAM_CHEESE    237.0  9.000  30.000   3880.000
# 13135          CHICKEN_NUGGETS_FAST-FOOD    241.0  3.000  10.000    281.000
# 13387                   ONION_MATURE_RAW    128.0  3.000  10.000     97.700
#
#          Element                                             Method  \
# 9944     CADMIUM                                                NaN
# 1974        IRON  KCM TD M2 & E1 (ICPAES; Ca, Cu, Fe, Mg, Mn, P,...
# 6266      SODIUM                                                NaN
# 13135  MAGNESIUM  KCM TD M2 & E1 (ICPAES; Ca, Cu, Fe, Mg, Mn, P,...
# 13387  MAGNESIUM  KCM TD M2 & E1 (ICPAES; Ca, Cu, Fe, Mg, Mn, P,...
#
#       Instrument        MB    Year Market_Basket
# 9944       GFAAS  200903.0  2009.0          03.0
# 1974      ICPAES  200201.0  2002.0          01.0
# 6266      ICPAES  200702.0  2007.0          02.0
# 13135     ICPAES  199604.0  1996.0          04.0
# 13387     ICPAES  200404.0  2004.0          04.0

# %% [markdown]
# For each food for each element, what are the counts

# %%
df_select['conc_indicator'] = \
df_select.apply(lambda row: '> LOQ' if row['Conc_mgkg'] > row['LOQ']\
                else ('trace' if row['Conc_mgkg'] <= row['LOQ'] and row['Conc_mgkg'] > row['LOD']\
                      else '< LOD')
                , axis=1)
# Out:
# C:\Users\carte\AppData\Local\Temp\ipykernel_10620\3062562691.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_select['conc_indicator'] = \

# %%
show(df_select)
# Out:
# <table id="itables_46f3f7e1_bfb2_4401_bb7d_0bc8aa4db43c" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Food_Name</th>
#       <th>Food_No</th>
#       <th>LOD</th>
#       <th>LOQ</th>
#       <th>Conc_mgkg</th>
#       <th>Element</th>
#       <th>Method</th>
#       <th>Instrument</th>
#       <th>MB</th>
#       <th>Year</th>
#       <th>Market_Basket</th>
#       <th>conc_indicator</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.1.3 from the <code>init_notebook_mode</code> cell...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <script type="module">
#     const { DataTable, jQuery: $ } = await import(window._datatables_src_for_itables_2_1_3);
#
#     document.querySelectorAll("#itables_46f3f7e1_bfb2_4401_bb7d_0bc8aa4db43c:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [[0, "WHOLE_MILK_FLUID", 1.0, 0.05, 0.14, 0.0, "ARSENIC", "LIB 1900 & Anal. Chem. (1976) 48, 120", "HGAAS", 199103.0, 1991.0, "03.0", "< LOD"], [1, "WHOLE_MILK_FLUID", 1.0, 0.002, 0.005, 0.0, "CADMIUM", "LIB 2403 (Modified)", "GFAAS", 199103.0, 1991.0, "03.0", "< LOD"], [2, "WHOLE_MILK_FLUID", 1.0, 3.0, 10.0, 261.0, "CALCIUM", "SARAP Project #10579", "ICPAES", 199103.0, 1991.0, "03.0", "> LOQ"], [3, "WHOLE_MILK_FLUID", 1.0, 0.25, 0.9, 0.0, "COPPER", "SARAP Project #10579", "ICPAES", 199103.0, 1991.0, "03.0", "< LOD"], [4, "WHOLE_MILK_FLUID", 1.0, 0.7, 3.0, 0.0, "IRON", "SARAP Project #10579", "ICPAES", 199103.0, 1991.0, "03.0", "< LOD"], [5, "WHOLE_MILK_FLUID", 1.0, 0.007, 0.03, 0.0, "LEAD", "LIB 2403 (Modified)", "GFAAS", 199103.0, 1991.0, "03.0", "< LOD"], [6, "WHOLE_MILK_FLUID", 1.0, 3.0, 10.0, 82.0, "MAGNESIUM", "SARAP Project #10579", "ICPAES", 199103.0, 1991.0, "03.0", "> LOQ"], [7, "WHOLE_MILK_FLUID", 1.0, 0.006, 0.02, 0.0, "MERCURY", "AOAC OMA 971.21", "CVAAS", 199103
K_FLUID", 2.0, 8.0, 30.0, 1550.0, "POTASSIUM", "SARAP Project #10579", "ICPAES", 199103.0, 1991.0, "03.0", "> LOQ"], [24, "LOWFAT_(2%_FAT)_MILK_FLUID", 2.0, 0.05, 0.14, 0.0, "SELENIUM", "LIB 1900 & Anal. Chem. (1976) 48, 120", "HGAAS", 199103.0, 1991.0, "03.0", "< LOD"], [25, "LOWFAT_(2%_FAT)_MILK_FLUID", 2.0, 7.0, 30.0, 442.0, "SODIUM", "SARAP Project #10579", "ICPAES", 199103.0, 1991.0, "03.0", "> LOQ"], [26, "LOWFAT_(2%_FAT)_MILK_FLUID", 2.0, 0.3, 0.9, 4.9, "ZINC", "SARAP Project #10579", "ICPAES", 199103.0, 1991.0, "03.0", "> LOQ"], [27, "CHOCOLATE_MILK_FLUID", 3.0, 0.05, 0.14, 0.0, "ARSENIC", "LIB 1900 & Anal. Chem. (1976) 48, 120", "HGAAS", 199103.0, 1991.0, "03.0", "< LOD"], [28, "CHOCOLATE_MILK_FLUID", 3.0, 0.002, 0.005, 0.0, "CADMIUM", "LIB 2403 (Modified)", "GFAAS", 199103.0, 1991.0, "03.0", "< LOD"], [29, "CHOCOLATE_MILK_FLUID", 3.0, 3.0, 10.0, 456.0, "CALCIUM",  ...

# %% [markdown]
# # Data Evaluation for Element Mass Fractions in Foods

# %% [markdown]
# How many < LOD, trace, and > LOQ in the dataset

# %%
df_FOM_count = df_select[['Food_Name', 'Element', 'conc_indicator']]\
    .value_counts()\
     .reset_index()

# %%
show(df_FOM_count
    )
# Out:
# <table id="itables_0b3cbe18_3810_4067_87cf_20dfbf035158" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>Food_Name</th>
#       <th>Element</th>
#       <th>conc_indicator</th>
#       <th>count</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.1.3 from the <code>init_notebook_mode</code> cell...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <script type="module">
#     const { DataTable, jQuery: $ } = await import(window._datatables_src_for_itables_2_1_3);
#
#     document.querySelectorAll("#itables_0b3cbe18_3810_4067_87cf_20dfbf035158:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [["EGGS_BOILED", "CADMIUM", "< LOD", 99], ["ENGLISH_MUFFIN_PLAIN_TOASTED", "CADMIUM", "> LOQ", 99], ["SPINACH_FRESH/FROZEN_BOILED", "CADMIUM", "> LOQ", 99], ["ENGLISH_MUFFIN_PLAIN_TOASTED", "SODIUM", "> LOQ", 98], ["GREEN_BEANS_FRESH/FROZEN_BOILED", "ARSENIC", "< LOD", 98], ["RAISIN_BRAN_CEREAL", "CADMIUM", "> LOQ", 98], ["CHICKEN_NUGGETS_FAST-FOOD", "POTASSIUM", "> LOQ", 98], ["TORTILLA_FLOUR", "CADMIUM", "> LOQ", 98], ["CHICKEN_NUGGETS_FAST-FOOD", "SODIUM", "> LOQ", 98], ["ENGLISH_MUFFIN_PLAIN_TOASTED", "POTASSIUM", "> LOQ", 98], ["ONION_MATURE_RAW", "POTASSIUM", "> LOQ", 98], ["CELERY_RAW", "POTASSIUM", "> LOQ", 98], ["CELERY_RAW", "SODIUM", "> LOQ", 98], ["SHRIMP_BOILED", "SODIUM", "> LOQ", 98], ["CEL
", "POTASSIUM", "> LOQ", 97], ["CELERY_RAW", "CADMIUM", "> LOQ", 97], ["QUARTER-POUND_CHEESEBURGER_ON_BUN_FAST-FOOD", "POTASSIUM", "> LOQ", 97], ["MIXED_VEGETABLES_FROZEN_BOILED", "POTASSIUM", "> LOQ", 97], ["CRISPED_RICE_CEREAL", "MANGANESE", "> LOQ", 97], ["POTATO_CHIPS", "MANGANESE", "> LOQ", 97], ["FRUIT_DRINK_FROM_POWDER", "ARSENIC", "< LOD", 97], ["CHICKEN_NUGGETS_FAST-FOOD", "MANGANESE", "> LOQ", 97], ["TOMATO_CATSUP", "POTASSIUM", "> LOQ", 97], ["PORK_AND_BEANS_CANNED", "SODIUM", "> LOQ", 97], ["TUNA_NOODLE_CASSEROLE_HOMEMADE", "POTASSIUM", "> LOQ", 97], ["SOUR_CREAM", "ARSENIC", "< LOD", 97], ["PORK_AND_BEANS_CANNED", "POTASSIUM", "> LOQ", 97], ["POTATO_CHIPS", "POTASSIUM", "> LOQ", 97], ["PORK_AND_BEANS_CANNED", "MANGANESE", "> LOQ", 97], ["POTATO_CHIPS", "SODIUM", "> LOQ", 97], ["MIXED_VEGETABLES_FROZEN_BOILED", "SODIUM", "> LOQ", 97], ["COFFEE_FROM_GROUND", "POTASSIUM", "> LOQ", 97], ["CRISPED_RICE_CEREAL", "POTASSIUM", "> LOQ", 97], ["RAISIN_BRAN_CEREAL", "MANGANESE", "> LOQ", 97], ["TOMATO_CATSUP", "SODIUM", "> LOQ", 97], ["QUARTER-POUND_HAMBURGER_ON_BUN_FAST-FOOD", "SODIUM", "> LOQ", 97], ["SOUR_CREAM", "POTASSIUM", "> LOQ", 97], ["BLACK_OLIVES", "SODIUM", "> LOQ", 97], ["CORN_FRESH ...

# %%
show(df_FOM_count.query('Element == "IRON"'))
# Out:
# <table id="itables_f95635bb_110b_4284_a4a1_a3165eb6d1b7" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Food_Name</th>
#       <th>Element</th>
#       <th>conc_indicator</th>
#       <th>count</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.1.3 from the <code>init_notebook_mode</code> cell...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <script type="module">
#     const { DataTable, jQuery: $ } = await import(window._datatables_src_for_itables_2_1_3);
#
#     document.querySelectorAll("#itables_f95635bb_110b_4284_a4a1_a3165eb6d1b7:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [[186, "ENGLISH_MUFFIN_PLAIN_TOASTED", "IRON", "> LOQ", 95], [219, "EGGS_BOILED", "IRON", "> LOQ", 95], [253, "FISH_SANDWICH_ON_BUN_FAST-FOOD", "IRON", "> LOQ", 94], [258, "SHREDDED_WHEAT_CEREAL", "IRON", "> LOQ", 94], [267, "CRISPED_RICE_CEREAL", "IRON", "> LOQ", 94], [291, "EGG_CHEESE_AND_HAM_ON_ENGLISH_MUFFIN_FAST-FOOD", "IRON", "> LOQ", 94], [297, "OAT_RING_CEREAL", "IRON", "> LOQ", 94], [307, "TEA_FROM_TEA_BAG", "IRON", "< LOD", 94], [310, "BEER", "IRON", "< LOD", 94], [315, "TORTILLA_FLOUR", "IRON", "> LOQ", 94], [341, "BLACK_OLIVES", "IRON", "> LOQ
OQ", 76], [659, "SOUR_CREAM", "IRON", "< LOD", 76], [681, "SUMMER_SQUASH_FRESH/FROZEN_BOILED", "IRON", "trace", 72], [694, "CELERY_RAW", "IRON", "trace", 71], [697, "JELLY_ANY_FLAVOR", "IRON", "trace", 70], [717, "HONEY", "IRON", "trace", 68], [737, "TOMATO_JUICE_BOTTLED", "IRON", "trace", 65], [757, "CREAM_CHEESE", "IRON", "< LOD", 62], [768, "DILL_CUCUMBER_PICKLES", "IRON", "trace", 61], [1216, "BOTTLED_DRINKING_WATER_(MINERAL/SPRING)_NOT_CARBONATED_OR_FLAVORED", "IRON", "< LOD", 58], [1304, "LAMB_CHOP_PAN-COOKED_WITH_OIL", "IRON", "> LOQ", 56], [1331, "BEEF_ROAST_CHUCK_OVEN-ROASTED", "IRON", "> LOQ", 56], [1367, "CAKE_CHOCOLATE_WITH_ICING", "IRON", "> LOQ", 56], [1383, "TOMATO_RAW", "IRON", "trace", 56], [1397, "MILK_SKIM_FLUID", "IRON", "< LOD", 56], [1402, "BREAD_WHOLE_WHEAT", "IRON", "> LOQ", 56], [1418, "BAGEL_PLAIN_TOASTED", "IRON", "> LOQ", 56], [1452, "BREAD_WHITE_ENRICHED", "IRON", "> LOQ", 56], [1487, "BEEF_GROUND_REGULAR_PAN-COOKED", "IRON", "> LOQ", 56], [1547, "MEATLOAF_BEEF_HOMEMADE", "IRON", "> LOQ", 55], [1568, "LIVER_(BEEF/CALF)_PAN-COOKED_WITH_OIL", "IRON", "> LOQ", 55], [1577, "MILK_WHOLE_FLUID", "IRON", "< LOD", 55], [1583, "BREAD_RYE", "IRON", "> LOQ", 55], [1595, "MUSTARD_YELLOW_PLAIN", "I ...

# %% [markdown]
# # Are There Trends in Element Mass Fractions for Certain Foods?

# %%
sns.regplot(df_select.query('Food_Name == "BANANAS_WITH_TAPIOCA_STRAINED/JUNIOR" and Element == "POTASSIUM"'),
                x = "Year",
                y = "Conc_mgkg",
                #hue = "Method",
               );

# %%
sns.regplot(df_select.query('Food_Name == "BANANA_RAW" and Element == "POTASSIUM"'),
                x = "Year",
                y = "Conc_mgkg",
                #hue = "Method",
               );

# %%
sns.regplot(df_select.query('Food_Name == "AVOCADO_RAW" and Element == "POTASSIUM"'),
                x = "Year",
                y = "Conc_mgkg",
                #hue = "Method",
               );

# %%
sns.regplot(df_select.query('Food_Name == "SUMMER_SQUASH_FRESH/FROZEN_BOILED" and Element == "POTASSIUM"'),
                x = "Year",
                y = "Conc_mgkg",
                #hue = "Method",
               );

# %%
sns.regplot(df_select.query('Food_Name == "TORTILLA_FLOUR" and Element == "CADMIUM"'),
                x = "Year",
                y = "Conc_mgkg",
                #hue = "Method",
               );

# %% [markdown]
# Summary of Element Mass Fractions for the Seleted Elements of Interest

# %%
ax = sns.boxplot(df_select.query('Conc_mgkg > LOQ'), x='Element', y = 'Conc_mgkg')
ax.set_yscale("log")
ax.tick_params(axis='x', rotation=90)

# %%
#df_select.to_csv("FDA_TDS_selected_elements.csv", index = False)
